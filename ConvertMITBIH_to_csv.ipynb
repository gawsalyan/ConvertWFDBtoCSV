# %% [markdown]
# # Convert all .dat and .atr files (ECG signals) in a folder to CSV format

# %%
"""
Code to convert all .dat files (ECG signals) in a folder to CSV format 
@author: Gawsalyan Sivapalan 
Thanks to Abhishek Patil
"""
import wfdb #WaveForm-Database package. A library of tools for reading, writing, and processing WFDB signals and annotations.
import pandas as pd
import numpy as np
import glob

# %%
db_path = 'MIT-BIH\\database\\mitdb\\'  #set your mitdb path

# %% [markdown]
# ##### DAT FILES

# %%
dat_files=glob.glob(db_path + '*.dat') #Get list of all .dat files in the current folder
#print(dat_files)
df=pd.DataFrame(data=dat_files)
df.to_csv("files_list.csv",index=False,header=None) #Write the list to a CSV file
files=pd.read_csv("files_list.csv",header=None)
#print(files)

for i in range(0,len(files)):
	recordname=str(files.iloc[i,0])
	print(recordname)
	recordname_new = recordname[:-4] #Extracting just the filename part (will differ from database to database)
	record = wfdb.rdsamp(recordname_new) # rdsamp() returns the signal as a numpy array  
	record = np.asarray(record[0])
	#print(record)    
	path=recordname_new + ".csv"
	np.savetxt(path,record,delimiter=",") #Writing the CSV for each record
	print("Files done: %s/%s"% (i,len(files)))

print("\nAll files done!")
# Out:
# MIT-BIH\database\mitdb\100.dat
# Files done: 0/48
# MIT-BIH\database\mitdb\101.dat
# Files done: 1/48
# MIT-BIH\database\mitdb\102.dat
# Files done: 2/48
# MIT-BIH\database\mitdb\103.dat
# Files done: 3/48
# MIT-BIH\database\mitdb\104.dat
# Files done: 4/48
# MIT-BIH\database\mitdb\105.dat
# Files done: 5/48
# MIT-BIH\database\mitdb\106.dat
# Files done: 6/48
# MIT-BIH\database\mitdb\107.dat
# Files done: 7/48
# MIT-BIH\database\mitdb\108.dat
# Files done: 8/48
# MIT-BIH\database\mitdb\109.dat
# Files done: 9/48
# MIT-BIH\database\mitdb\111.dat
# Files done: 10/48
# MIT-BIH\database\mitdb\112.dat
# Files done: 11/48
# MIT-BIH\database\mitdb\113.dat
# Files done: 12/48
# MIT-BIH\database\mitdb\114.dat
# Files done: 13/48
# MIT-BIH\database\mitdb\115.dat
# Files done: 14/48
# MIT-BIH\database\mitdb\116.dat
# Files done: 15/48
# MIT-BIH\database\mitdb\117.dat
# Files done: 16/48
# MIT-BIH\database\mitdb\118.dat
# Files done: 17/48
# MIT-BIH\database\mitdb\119.dat
# Files done: 18/48
# MIT-BIH\database\mitdb\121.dat
# Files done: 19/48
# MIT-BIH\database\mitdb\122.dat
# Files done: 20/48
# MIT-BIH\database\mitdb\123.dat
# Files done: 21/48
# MIT-BIH\database\mitdb\124.dat
# Files done: 22/48
# MIT-BIH\database\mitdb\200.dat
# Files done: 23/48
# MIT-BIH\database\mitdb\201.dat
# Files done: 24/48
# MIT-BIH\database\mitdb\202.dat
# Files done: 25/48
# MIT-BIH\database\mitdb\203.dat
# Files done: 26/48
# MIT-BIH\database\mitdb\205.dat
# Files done: 27/48
# MIT-BIH\database\mitdb\207.dat
# Files done: 28/48
# MIT-BIH\database\mitdb\208.dat
# Files done: 29/48
# MIT-BIH\database\mitdb\209.dat
# Files done: 30/48
# MIT-BIH\database\mitdb\210.dat
# Files done: 31/48
# MIT-BIH\database\mitdb\212.dat
# Files done: 32/48
# MIT-BIH\database\mitdb\213.dat
# Files done: 33/48
# MIT-BIH\database\mitdb\214.dat
# Files done: 34/48
# MIT-BIH\database\mitdb\215.dat
# Files done: 35/48
# MIT-BIH\database\mitdb\217.dat
# Files done: 36/48
# MIT-BIH\database\mitdb\219.dat
# Files done: 37/48
# MIT-BIH\database\mitdb\220.dat
# Files done: 38/48
# MIT-BIH\database\mitdb\221.dat
# Files done: 39/48
# MIT-BIH\database\mitdb\222.dat
# Files done: 40/48
# MIT-BIH\database\mitdb\223.dat
# Files done: 41/48
# MIT-BIH\database\mitdb\228.dat
# Files done: 42/48
# MIT-BIH\database\mitdb\230.dat
# Files done: 43/48
# MIT-BIH\database\mitdb\231.dat
# Files done: 44/48
# MIT-BIH\database\mitdb\232.dat
# Files done: 45/48
# MIT-BIH\database\mitdb\233.dat
# Files done: 46/48
# MIT-BIH\database\mitdb\234.dat
# Files done: 47/48
#
# All files done!

# %% [markdown]
# ##### ANN FILES

# %%
dat_files=glob.glob(db_path + '*.atr') #Get list of all .dat files in the current folder
#print(dat_files)
df=pd.DataFrame(data=dat_files)
df.to_csv("files_list.csv",index=False,header=None) #Write the list to a CSV file
files=pd.read_csv("files_list.csv",header=None)
#print(files)

for i in range(0,len(files)):
	recordname=str(files.iloc[i,0])
	print(recordname)
	recordname_new=recordname[:-4] #Extracting just the filename part (will differ from database to database)
	annotation = wfdb.rdann(recordname_new, 'atr') # rdsamp() returns the signal as a numpy array
	ann_sample = np.asarray(annotation.sample)  
	ann_symbol = np.asarray(annotation.symbol)
	annotation=np.column_stack((ann_sample,ann_symbol))
	#print(annotation)
	path=recordname_new + ".ann"
	np.savetxt(path,annotation,delimiter=",",fmt='%s') #Writing the CSV for each record
	print("Files done: %s/%s"% (i,len(files)))

print("\nAll files done!")
# Out:
# MIT-BIH\database\mitdb\100.atr
# [['18' '+']
#  ['77' 'N']
#  ['370' 'N']
#  ...
#  ['649484' 'N']
#  ['649734' 'N']
#  ['649991' 'N']]
# Files done: 0/48
# MIT-BIH\database\mitdb\101.atr
# [['7' '+']
#  ['83' 'N']
#  ['396' 'N']
#  ...
#  ['649004' 'N']
#  ['649372' 'N']
#  ['649751' 'N']]
# Files done: 1/48
# MIT-BIH\database\mitdb\102.atr
# [['68' '+']
#  ['136' '/']
#  ['410' '/']
#  ...
#  ['649244' '/']
#  ['649553' '/']
#  ['649852' '/']]
# Files done: 2/48
# MIT-BIH\database\mitdb\103.atr
# [['21' '+']
#  ['265' 'N']
#  ['575' 'N']
#  ...
#  ['649195' 'N']
#  ['649534' 'N']
#  ['649875' 'N']]
# Files done: 3/48
# MIT-BIH\database\mitdb\104.atr
# [['36' '+']
#  ['73' '/']
#  ['316' '/']
#  ...
#  ['649300' '/']
#  ['649580' '/']
#  ['649876' '/']]
# Files done: 4/48
# MIT-BIH\database\mitdb\105.atr
# [['67' '+']
#  ['197' 'N']
#  ['459' 'N']
#  ...
#  ['649221' 'N']
#  ['649471' 'N']
#  ['649740' 'N']]
# Files done: 5/48
# MIT-BIH\database\mitdb\106.atr
# [['83' '~']
#  ['229' '+']
#  ['351' 'N']
#  ...
#  ['649162' 'V']
#  ['649340' 'V']
#  ['649791' 'N']]
# Files done: 6/48
# MIT-BIH\database\mitdb\107.atr
# [['47' '+']
#  ['95' '/']
#  ['272' '/']
#  ...
#  ['649129' '/']
#  ['649441' '/']
#  ['649748' '/']]
# Files done: 7/48
# MIT-BIH\database\mitdb\108.atr
# [['23' '+']
#  ['88' 'N']
#  ['442' 'N']
#  ...
#  ['649170' 'N']
#  ['649471' 'N']
#  ['649769' 'N']]
# Files done: 8/48
# MIT-BIH\database\mitdb\109.atr
# [['18' '+']
#  ['111' 'L']
#  ['343' 'L']
#  ...
#  ['649378' 'L']
#  ['649663' 'L']
#  ['649931' 'L']]
# Files done: 9/48
# MIT-BIH\database\mitdb\111.atr
# [['31' '+']
#  ['197' 'L']
#  ['489' 'L']
#  ...
#  ['649148' 'L']
#  ['649441' 'L']
#  ['649724' 'L']]
# Files done: 10/48
# MIT-BIH\database\mitdb\112.atr
# [['15' '+']
#  ['124' 'N']
#  ['382' 'N']
#  ...
#  ['649361' 'N']
#  ['649626' 'N']
#  ['649883' 'N']]
# Files done: 11/48
# MIT-BIH\database\mitdb\113.atr
# [['22' '+']
#  ['170' 'N']
#  ['583' 'N']
#  ...
#  ['649364' 'N']
#  ['649675' 'N']
#  ['649994' 'N']]
# Files done: 12/48
# MIT-BIH\database\mitdb\114.atr
# [['21' '+']
#  ['310' 'N']
#  ['726' 'N']
#  ...
#  ['649261' 'N']
#  ['649523' 'N']
#  ['649783' 'N']]
# Files done: 13/48
# MIT-BIH\database\mitdb\115.atr
# [['44' '+']
#  ['161' 'N']
#  ['518' 'N']
#  ...
#  ['649357' 'N']
#  ['649647' 'N']
#  ['649955' 'N']]
# Files done: 14/48
# MIT-BIH\database\mitdb\116.atr
# [['174' '+']
#  ['282' 'N']
#  ['561' 'N']
#  ...
#  ['649442' 'N']
#  ['649701' 'N']
#  ['649957' 'N']]
# Files done: 15/48
# MIT-BIH\database\mitdb\117.atr
# [['72' '+']
#  ['189' 'N']
#  ['598' 'N']
#  ...
#  ['649070' 'N']
#  ['649498' 'N']
#  ['649926' 'N']]
# Files done: 16/48
# MIT-BIH\database\mitdb\118.atr
# [['13' '+']
#  ['68' 'R']
#  ['369' 'R']
#  ...
#  ['649226' 'R']
#  ['649429' 'A']
#  ['649742' 'R']]
# Files done: 17/48
# MIT-BIH\database\mitdb\119.atr
# [['32' '+']
#  ['309' 'N']
#  ['503' 'V']
#  ...
#  ['649129' 'N']
#  ['649468' 'N']
#  ['649788' 'N']]
# Files done: 18/48
# MIT-BIH\database\mitdb\121.atr
# [['36' '+']
#  ['163' 'N']
#  ['513' 'N']
#  ...
#  ['649287' 'N']
#  ['649587' 'N']
#  ['649878' 'N']]
# Files done: 19/48
# MIT-BIH\database\mitdb\122.atr
# [['17' '+']
#  ['93' 'N']
#  ['326' 'N']
#  ...
#  ['649383' 'N']
#  ['649643' 'N']
#  ['649905' 'N']]
# Files done: 20/48
# MIT-BIH\database\mitdb\123.atr
# [['25' '+']
#  ['70' 'N']
#  ['550' 'N']
#  ...
#  ['648997' 'N']
#  ['649342' 'N']
#  ['649689' 'N']]
# Files done: 21/48
# MIT-BIH\database\mitdb\124.atr
# [['100' '+']
#  ['243' 'R']
#  ['693' 'R']
#  ...
#  ['649146' 'R']
#  ['649510' 'R']
#  ['649876' 'R']]
# Files done: 22/48
# MIT-BIH\database\mitdb\200.atr
# [['67' '+']
#  ['225' 'V']
#  ['487' 'N']
#  ...
#  ['649408' 'N']
#  ['649664' 'N']
#  ['649927' 'N']]
# Files done: 23/48
# MIT-BIH\database\mitdb\201.atr
# [['60' '+']
#  ['159' 'N']
#  ['415' 'N']
#  ...
#  ['649104' 'N']
#  ['649181' 'x']
#  ['649800' 'N']]
# Files done: 24/48
# MIT-BIH\database\mitdb\202.atr
# [['183' '+']
#  ['348' 'N']
#  ['742' 'N']
#  ...
#  ['649342' 'N']
#  ['649615' 'N']
#  ['649877' 'N']]
# Files done: 25/48
# MIT-BIH\database\mitdb\203.atr
# [['14' '+']
#  ['24' '~']
#  ['99' 'N']
#  ...
#  ['649237' 'N']
#  ['649448' 'N']
#  ['649777' 'N']]
# Files done: 26/48
# MIT-BIH\database\mitdb\205.atr
# [['15' '+']
#  ['229' 'N']
#  ['466' 'N']
#  ...
#  ['649326' 'N']
#  ['649596' 'N']
#  ['649857' 'N']]
# Files done: 27/48
# MIT-BIH\database\mitdb\207.atr
# [['9' '+']
#  ['50' 'R']
#  ['312' 'V']
#  ...
#  ['649431' 'A']
#  ['649602' 'A']
#  ['649799' 'A']]
# Files done: 28/48
# MIT-BIH\database\mitdb\208.atr
# [['9' '+']
#  ['46' 'F']
#  ['209' 'V']
#  ...
#  ['649411' 'V']
#  ['649704' 'N']
#  ['649935' 'N']]
# Files done: 29/48
# MIT-BIH\database\mitdb\209.atr
# [['84' '+']
#  ['189' 'N']
#  ['425' 'N']
#  ...
#  ['649387' 'N']
#  ['649627' 'N']
#  ['649857' 'N']]
# Files done: 30/48
# MIT-BIH\database\mitdb\210.atr
# [['13' '+']
#  ['57' 'N']
#  ['250' 'N']
#  ...
#  ['649513' 'V']
#  ['649758' 'N']
#  ['649962' 'N']]
# Files done: 31/48
# MIT-BIH\database\mitdb\212.atr
# [['125' '+']
#  ['214' 'R']
#  ['451' 'R']
#  ...
#  ['649414' 'N']
#  ['649673' 'N']
#  ['649945' 'N']]
# Files done: 32/48
# MIT-BIH\database\mitdb\213.atr
# [['18' '+']
#  ['95' 'N']
#  ['253' 'N']
#  ...
#  ['649577' 'N']
#  ['649790' 'N']
#  ['649992' 'N']]
# Files done: 33/48
# MIT-BIH\database\mitdb\214.atr
# [['19' '+']
#  ['58' 'L']
#  ['346' 'L']
#  ...
#  ['649379' 'L']
#  ['649627' 'L']
#  ['649891' 'L']]
# Files done: 34/48
# MIT-BIH\database\mitdb\215.atr
# [['41' '+']
#  ['124' 'N']
#  ['313' 'N']
#  ...
#  ['649501' 'N']
#  ['649685' 'N']
#  ['649875' 'N']]
# Files done: 35/48
# MIT-BIH\database\mitdb\217.atr
# [['102' '+']
#  ['205' '/']
#  ['500' '/']
#  ...
#  ['649114' '/']
#  ['649429' '/']
#  ['649738' '/']]
# Files done: 36/48
# MIT-BIH\database\mitdb\219.atr
# [['188' '+']
#  ['300' 'N']
#  ['614' 'N']
#  ...
#  ['649174' 'N']
#  ['649448' 'N']
#  ['649737' 'N']]
# Files done: 37/48
# MIT-BIH\database\mitdb\220.atr
# [['0' '+']
#  ['28' 'N']
#  ['313' 'N']
#  ...
#  ['649277' 'N']
#  ['649584' 'N']
#  ['649904' 'N']]
# Files done: 38/48
# MIT-BIH\database\mitdb\221.atr
# [['28' '+']
#  ['220' 'N']
#  ['442' 'N']
#  ...
#  ['649236' 'N']
#  ['649530' 'N']
#  ['649810' 'N']]
# Files done: 39/48
# MIT-BIH\database\mitdb\222.atr
# [['17' '+']
#  ['81' 'N']
#  ['361' 'N']
#  ...
#  ['649317' 'N']
#  ['649600' 'N']
#  ['649859' 'N']]
# Files done: 40/48
# MIT-BIH\database\mitdb\223.atr
# [['96' '+']
#  ['204' 'N']
#  ['480' 'N']
#  ...
#  ['649349' 'N']
#  ['649599' 'N']
#  ['649849' 'N']]
# Files done: 41/48
# MIT-BIH\database\mitdb\228.atr
# [['27' '+']
#  ['160' 'N']
#  ['433' 'N']
#  ...
#  ['649108' 'N']
#  ['649332' 'V']
#  ['649761' 'N']]
# Files done: 42/48
# MIT-BIH\database\mitdb\230.atr
# [['30' '+']
#  ['75' 'N']
#  ['349' 'N']
#  ...
#  ['649338' 'N']
#  ['649572' 'N']
#  ['649807' 'N']]
# Files done: 43/48
# MIT-BIH\database\mitdb\231.atr
# [['57' '+']
#  ['180' 'R']
#  ['527' 'R']
#  ...
#  ['649142' 'R']
#  ['649501' 'R']
#  ['649862' 'R']]
# Files done: 44/48
# MIT-BIH\database\mitdb\232.atr
# [['76' '+']
#  ['491' 'R']
#  ['737' 'A']
#  ...
#  ['648845' 'R']
#  ['649097' 'A']
#  ['649366' 'A']]
# Files done: 45/48
# MIT-BIH\database\mitdb\233.atr
# [['3' '+']
#  ['42' 'V']
#  ['320' 'N']
#  ...
#  ['649518' 'N']
#  ['649730' 'N']
#  ['649946' 'N']]
# Files done: 46/48
# MIT-BIH\database\mitdb\234.atr
# [['52' '+']
#  ['135' 'N']
#  ['366' 'N']
#  ...
#  ['649292' 'N']
#  ['649536' 'N']
#  ['649772' 'N']]
# Files done: 47/48
#
# All files done!
